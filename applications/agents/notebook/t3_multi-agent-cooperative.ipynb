# %% [markdown]
# # 1. multi-agent-competitive 合作型 - 两个大模型相互对话

# %% [markdown]
# 首先将 wde 目录加入python path

# %%
import os
import sys
from pathlib import Path
pwd = Path(os.getcwd())
sys.path.append(str(pwd.parent.parent.parent))
os.chdir(str(pwd.parent.parent.parent))

# %% [markdown]
# 导入RolePlayingAgent、SummaryAgent、Session 后续会介绍

# %%
from wde.agents import RolePlayingAgent
from wde.agents import SummaryAgent
from wde.agents import Session

# %% [markdown]
# 设定 llm 参数

# %%
llm_config = {"model": "Qwen/Qwen2-7B-Instruct", "type": "zeroclient"}

# %% [markdown]
# 加入第一个llm驱动的角色：乔，营销策划。

# %%
joe = RolePlayingAgent(
    name="乔",
    system_message=
    "你的名字叫乔，你是一名营销策划。"
    "你会根据产品制定营销策划方案。",
    llm_config=llm_config,
)

# %% [markdown]
# 加入第二个llm驱动的角色：周，文案策划。

# %%
zhou = RolePlayingAgent(
    name="周",
    system_message=
    "你的名字叫周，你是一名文案策划。"
    "你根据营销策划方案提供不同平台的具体文案",
    llm_config=llm_config,
)

# %% [markdown]
# 将joe和zhou加入拉进同一个会话

# %%
session = Session(participants=[joe,zhou])

# %% [markdown]
# joe 先开始对话。（必须人工开始对话，两个Agent拉进同一个会话不知道怎么开始对话。)

# %%
session.append((zhou, "我们此次的产品是健身课程"))

# %% [markdown]
# 进行两轮对话

# %%
session.chat(max_turns=2)
# Out:
# 周 (round 0)
#
# 我们此次的产品是健身课程
#
# 乔 (round 0)
#
# 为健身课程制定营销策划方案时，我们第一步要做的是精准定位目标市场和了解竞争对手。然后根据目标市场的需求和特点，设计一套涵盖线上线下多渠道的推广策略。以下是一个基于健身课程的营销策划方案：
#
# ### 1. 市场调研与定位
#
# - **目标市场定位**: 首先，识别主要目标市场，包括年龄、性别、职业、兴趣偏好等因素。例如，年轻人、健身爱好者、办公室职员等。
# - **竞品分析**: 分析竞争对手的产品特点、用户评价、营销策略等，找到差异化的卖点。
#
# ### 2. 产品特色与价值主张
#
# - **独特卖点**: 识别和强调健身课程的独特之处，如专业教练、个性化训练计划、远程服务（在线课程）、社区互动等。
# - **价值主张**: 主张如何帮助用户实现健身目标，如增强体质、减脂塑形、改善生活质量等。
#
# ### 3. 营销策略设计
#
# #### 线上渠道
#
# - **社交媒体营销**: 利用如微信、微博、抖音、小红书等平台，发布有趣的健身小知识、培训案例和个人成功故事的分享，提高品牌曝光度。
# - **内容营销**: 制作健身教程、营养知识文章、客户案例分析等，吸引潜在用户关注。
# - **付费广告**: 在社交媒体和搜索引擎等平台上投放广告，针对特定人群进行精准推广。
# - **在线直播**: 定期举行在线健身培训直播，邀请专业教练和知名健身爱好者分享经验。
#
# #### 线下渠道
#
# - **活动营销**: 定期举办线下健身竞赛、讲座或体验课程，促进口碑传播。
# - **合作伙伴**: 与健身房、运动装备品牌、健康管理公司等建立合作关系，共享用户资源。
#
# ### 4. 售后服务与用户忠诚度
#
# - **个性化服务**: 提供个性化的健身计划和营养建议，以及定期的进度跟踪和调整服务。
# - **会员福利**: 设计会员积分系统、特殊折扣、优先培训邀请等，增强用户忠诚度。
# - **用户反馈与改进**: 活跃用户社区，收集用户反馈并定期更新课程内容和提高服务质量。
#
# ### 5. 预算与执行计划
#
# - **预算分配**: 预算按线上营销、线下活动、人才培训、客户服务等多个方面合理分配。
# - **执行时间表**: 制定详细的执行时间表，包括工作里程碑、关键任务截止日期等。
#
# ### 6. 效果评估与优化
#
# - **关键指标**: 确定评估效果的关键指标，如用户增长、转化率、客户留存率等。
# - **数据追踪**: 使用营销工具进行数据追踪，定期分析结果并进行调整优化。
#
# 通过上述策略的实施，旨在有效地将健身课程推广到目标市场，吸引并保留用户，同时持续优化产品和服务，提升品牌影响力和市场竞争力。
#
# ================================================================================
# 周 (round 1)
#
# 确实如你所述，制定一个系统且全面的营销策划方案是成功推广健身课程的关键。我将依照方案内容为您细化出各平台的文案策略，让沟通更加精准且有吸引力。以下建议分别对应于社交媒体营销、内容营销、在线直播以及线下活动等不同渠道：
#
# ### 1. 社交媒体营销
# **微信公众号：动感世界精选**
# ---
# 标题：🔥“力量的魔法”限时解锁：塑身大师线上课程，让健身成为生活方式！🌈
# 正文：
# 亲爱的健身爱好者们，现在是你们改变身体、提升信心的最佳时机！我们的专业健身教练团队推出全新在线课程，针对性更强，个性化更为深入。在这里，你将不仅学习到科学的训练方法，更能在社区中找到志同道合的伙伴，一起挑战自我，实现梦想体型。立即订阅，让“动感世界精选”成为你健身路上的强有力伙伴！🚀
# **标签关键词：在线健身课程 塑身大师 动感世界**
# ---
# **微博：健身新境界**
# ---
# 标题：💪******“健身新】境界“，免费体验课等你来！✨******
# 正文：
# 挑战自我，释放潜能！健身不仅仅是为了外在的改变，更是心灵的洗礼和自信的源泉。为了让更多人体验到健身带来的奇迹，我们特别开设【免费体验课】及【立减优惠】，邀请你加入这场健康与美丽的旅程。不论是新手小白还是资深健身达人，我们的教练团队将为你量身定制训练计划，帮你更高效地达成目标。即刻行动，开启你的【健身新境界】之旅！🌟
# **标签关键词：免费体验课 立减优惠 健身新境界**
#
# ### 2. 内容营销
# **博客文章：燃烧卡路里的秘密**
# ---
# 标题：🔥揭秘：最有效的燃脂技巧，让你轻松告别赘肉！💢
# 正文：
# 在这个追求快速瘦身的时代，找到真正有效的燃脂方法变得尤为关键。今天，让我们一起揭秘那些被低估的燃脂策略，带你彻底告别赘肉，重塑完美身材。文章将深入解析如何结合正确的饮食、科学健身和充足休息，打造个人化的减脂计划。无论是健身新手还是资深玩家，都能从中学到实用技巧，打破减脂瓶颈，让健身真正成为一段快乐而高效的生活方式。立即开启你的减脂之旅，让我们一起燃烧脂肪，迎接光彩照人的自己！✨
# **标签关键词：燃脂技巧 减脂策略 个人化减脂计划**
#
# ### 3. 在线直播
# **直播预告：急速燃脂训练，与健身大神面对面！🔥**
# ---
# \*直播内容：\*快节奏与高效并重的燃脂训练课程，邀请知名专业教练为你在线讲解核心动作，解答训练中的常见问题，以及分享独家减脂秘籍。直播期间还有互动环节，参与问答即有机会抽取精美健身礼包！
#
# **直播时间：**
# 直播时间：每周末19:00-20:30
# 活动链接：请访问我们的网站获取直播链接，并关注现场答疑和奖品掉落时刻！
#
# **邀请理由：**
# 在这个追求快速成果的时代，与其独自摸索，不如让大神亲自为你点拨，让你的健身之路更加高效畅快！直播间见，让我们一起在健身的道路上同进同出！💪
# **标签关键词：快速燃脂 独家秘籍 高效训练**
#
# ### 4. 下线活动
# **社区活动：动力无限·健身挑战赛**
# ---
# 标题：🏆 动力无限·健身挑战赛，等你来战！(thread)
# 正文：
# 你，敢挑战吗？在这个充满活力的季节，【动力无限·健身挑战赛】正式启幕！无需健身房，无需特定设备，只需一颗热血炙热的心，挑战自我，超越极限。活动将持续四周，每周设定不同的健身目标，完成即可获得积分，累积分值最高的参与者将赢得【豪华健身装备大礼包】及其他惊喜奖品。报名方式已在网站展示，快扫描二维码或点击链接参与，一起点燃你的健身热情，让生活因挑战而精彩！🔥
# **标签关键词：健身挑战赛 超越极限 豪华健身装备**
#
# 这些文案旨在根据不同平台的特点和用户偏好，精准传达健身课程的价值和独特卖点，同时激发用户参与和互动，最终实现营销目标。
#
# 乔 (round 1)
#
# 这套营销方案将通过社交媒体、内容营销、在线直播及线下活动等多个渠道的综合运用，实现了品牌信息的多维度传播，不仅提供了专业权威的健身指导，还增加了用户体验的互动性和参与感。通过树立积极、高效、个性化的品牌形象，增强品牌与用户之间的链接，促使潜在用户从认知、兴趣到行动，最终成为忠实用户。同时，各平台文案的精心设计，围绕课程的主旨“塑身大师”、“健身新境界”、“燃烧卡路里的秘密”和“动力无限”的核心概念，提升了内容的吸引力和强烈的品牌调性。活动和直播的互动性设计，启发用户的探索欲和参与感，同时通过与专业健身教练的直接交流，提供专业指导，提升了课程服务的个性化和专业性。整个方案旨在构建一个全方位、多层次的健身参与平台，满足不同健身需求的用户，强化品牌形象，促进用户粘性和品牌忠诚度的提升。
#
# ================================================================================

# %% [markdown]
# 由SummaryAgent总结对话

# %%
summary_agent = SummaryAgent(
    system_message="总结下面对话",
    llm_config=llm_config)

print("总结:")
print(summary_agent.summary(session))
# Out:
# 总结:
# 这段对话讨论了健身课程的营销策划方案。周和乔协同制定了一个系统全面的营销策略，以推广其健身课程。他们首先讨论了定位目标市场和竞争对手分析的重要性，然后详细规划了一系列基于线上线下的营销活动。
#
# 策略分为以下几个部分：
#
# 1. 市场调研与定位，识别目标市场，如年轻人、健身爱好者、办公室职员等，并分析竞争对手的产品特点和用户反馈。
# 2. 产品特色与价值主张，强调独特卖点，如专业教练、个性化训练计划、远程服务等，以及如何帮助用户实现健身目标。
# 3. 营销策略设计，提供详细线上（通过社交媒体营销、内容营销和在线直播）和线下（通过活动营销和合作伙伴关系）渠道的建议。
# 4. 售后服务与用户忠诚度建设，包括个性化服务、会员福利和用户反馈机制。
# 5. 预算与执行计划，预算分配和详细执行时间表。
# 6. 效果评估与优化，通过关键指标追踪营销效果，并持续调整优化策略。
#
# 其中，文案策略具体化了各平台的推广策略，如微信公众号、微博、博客和旗下直播平台，设计了针对不同平台特性、受众偏好的创意宣传文案和活动预热，以吸引并维持用户的兴趣。
#
# 最终，这套营销方案旨在通过多样化渠道推广，塑造专业的品牌形象，激发用户参与，提升品牌影响力，最终吸引和保留用户，增强用户忠诚度，实现成功营销。

# %% [markdown]
# 当角色较少时，使用一个agent足够。但当角色较多时，多个agent会使结果更加清晰。
